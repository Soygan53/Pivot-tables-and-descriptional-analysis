# %% [markdown]
# TASK-4B:Please provide the visual illustrations of the dataset that will demonstrate the insightful distributions with respect to the target column (CDRGLOB:the level of the Alzheimer Disease-AD)

# %%
"""
Created on Thursday Nov 06 13:04:11 2022

@author: Ahmet Sina Soykan
"""

import numpy as np                                  #importing libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd         

data=pd.read_excel("Temporary_data3_-_Copy.xlsx")   #read the file
x = data["HIPPOVOL"]                                 #plotting Hippovol-Naccmmse Values for CDRGLOB
y = data["NACCMMSE"]
labels = data["CDRGLOB"]
plt.scatter(x,y, cmap='viridis',c=labels, alpha=0.5)
plt.xlabel('Hippovol Value')
plt.ylabel('Naccmmse Value')
plt.title('Hippovol-Naccmmse for CDRGLOB')
plt.colorbar()
plt.show()
